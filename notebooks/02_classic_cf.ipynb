# %% [markdown]
# # Session 2 — Classic Collaborative Filtering
# This notebook will cover user/item-based CF and matrix factorization baselines.

# %%
# Load libraries
import pandas as pd
print('Notebook stub for Session 2')
